# %% [markdown]
# <a href="https://colab.research.google.com/github/ParkHangah/AIFFEL_quest_eng/blob/master/MLOps/MLOps01/Serving_models_via_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img width="180" alt="ops" src="data:image/png;base64,..." />
#
# 3. PyTorch를 통한 모델 서빙

# %%
# !pip install datasets torchserve torch-model-archiver torch-workflow-archiver nvgpu
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: torchserve in /usr/local/lib/python3.12/dist-packages (0.12.0)
# Requirement already satisfied: torch-model-archiver in /usr/local/lib/python3.12/dist-packages (0.12.0)
# Requirement already satisfied: torch-workflow-archiver in /usr/local/lib/python3.12/dist-packages (0.2.15)
# Requirement already satisfied: nvgpu in /usr/local/lib/python3.12/dist-packages (0.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.25.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (1.10.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from torchserve) (11.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from torchserve) (5.9.5)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (from torchserve) (0.46.3)
# Requirement already satisfied: enum-compat in /usr/local/lib/python3.12/dist-packages (from torch-model-archiver) (0.0.3)
# Requirement already satisfied: ansi2html in /usr/local/lib/python3.12/dist-packages (from nvgpu) (1.9.2)
# Requirement already satisfied: arrow in /usr/local/lib/python3.12/dist-packages (from nvgpu) (1.4.0)
# Requirement already satisfied: flask in /usr/local/lib/python3.12/dist-packages (from nvgpu) (3.1.3)
# Requirement already satisfied: flask-restful in /usr/local/lib/python3.12/dist-packages (from nvgpu) (0.3.10)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from nvgpu) (1.17.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from nvgpu) (3.3.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from nvgpu) (0.9.0)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.12/dist-packages (from nvgpu) (13.0.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2026.2.25)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from arrow->nvgpu) (2.9.0.post0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.12/dist-packages (from arrow->nvgpu) (2026.1)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask->nvgpu) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from flask->nvgpu) (8.3.2)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask->nvgpu) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from flask->nvgpu) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask->nvgpu) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from flask->nvgpu) (3.1.8)
# Requirement already satisfied: aniso8601>=0.82 in /usr/local/lib/python3.12/dist-packages (from flask-restful->nvgpu) (10.0.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from flask-restful->nvgpu) (2025.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from pynvml->nvgpu) (13.595.45)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.24.0->datasets) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.24.0->datasets) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.24.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.24.0->datasets) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.24.0->datasets) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.24.0->datasets) (0.1.2)

# %%
import torch
from torch.optim import AdamW
import torch.nn.functional as F
import matplotlib.pyplot as plt
import seaborn as sns

from torch.utils.data import DataLoader
from transformers import BatchEncoding, BertTokenizer, BertForSequenceClassification
from sklearn.metrics import confusion_matrix
from datasets import load_dataset
from tqdm import tqdm
from typing import TypedDict

# %% [markdown]
# PyTorch 1.12 버전 이후부터 transformers.AdamW 대신 torch.optim.AdamW 사용

# %%
dataset = load_dataset("ag_news")
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertForSequenceClassification.from_pretrained("bert-base-uncased", num_labels=4)
optimizer = AdamW(model.parameters(), lr=5e-5)
criterion = torch.nn.CrossEntropyLoss()

class DatasetItem(TypedDict):
    text: str
    label: str


def preprocess_data(dataset_item: DatasetItem) -> dict[str, torch.Tensor]:
    return tokenizer(dataset_item["text"], truncation=True, padding="max_length", return_tensors="pt")


train_dataset = dataset["train"].select(range(1200)).map(preprocess_data, batched=True)
test_dataset = dataset["test"].select(range(800)).map(preprocess_data, batched=True)

train_dataset.set_format("torch", columns=["input_ids", "attention_mask", "label"])
test_dataset.set_format("torch", columns=["input_ids", "attention_mask", "label"])

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# data/train-00000-of-00001.parquet:   0%|          | 0.00/18.6M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/1.23M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/120000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/7600 [00:00<?, ? examples/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Map:   0%|          | 0/1200 [00:00<?, ? examples/s]
# Map:   0%|          | 0/800 [00:00<?, ? examples/s]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

num_epochs = 3
losses: list[float] = []

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for batch in tqdm(train_loader, desc=f"Epoch {epoch + 1}"):
        inputs = {key: batch[key].to(device) for key in batch}
        labels = inputs.pop("label")
        outputs = model(**inputs, labels=labels)
        loss = outputs.loss
        total_loss += loss.item()
        losses.append(loss.item())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    average_loss = total_loss / len(train_loader)
    print(f"Epoch {epoch + 1}, Average Loss: {average_loss}")
# Out:
# Epoch 1: 100%|██████████| 150/150 [00:46<00:00,  3.20it/s]
# Epoch 1, Average Loss: 0.6453411335249742
# Epoch 2: 100%|██████████| 150/150 [00:47<00:00,  3.15it/s]
# Epoch 2, Average Loss: 0.278938600247105
# Epoch 3: 100%|██████████| 150/150 [00:48<00:00,  3.07it/s]
# Epoch 3, Average Loss: 0.16294932891925176

# %%
plt.figure(figsize=(12, 6))
plt.plot(losses, color="#4285f4", linewidth=2)
plt.xlabel("Step")
plt.ylabel("Loss")
plt.title("Training Loss per Step Across Epochs")
plt.show()

# %% [markdown]
# ## 모델 평가

# %%
model.eval()
correct = 0
total = 0

with torch.no_grad():
    for batch in tqdm(test_loader, desc="Evaluating"):
        inputs = {key: batch[key].to(device) for key in batch}
        labels = inputs.pop("label")
        outputs = model(**inputs, labels=labels)
        logits = outputs.logits
        predicted_labels = torch.argmax(logits, dim=1)
        correct += (predicted_labels == labels).sum().item()
        total += labels.size(0)

accuracy = correct / total

print("")
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# Evaluating: 100%|██████████| 100/100 [00:11<00:00,  8.98it/s]
# Test Accuracy: 83.88%

# %%
test_input = "[Official] 'Legendary Coach Resigns → Appoints New Commander' Suwon Completes Coaching Staff... Scout Bae Ki-jong Joins + Coach Shin Hwa-yong Remains"
test_input_processed = tokenizer(test_input, truncation=True, padding="max_length", return_tensors="pt").to(device)
logits = model(**test_input_processed).logits
print(logits)
predicted_labels = torch.argmax(logits, dim=1)

labeling_mapper = ["world", "sports", "business", "sci/tech"]
print(labeling_mapper[predicted_labels[0]])
# Out:
# tensor([[ 1.4194,  3.2910, -1.8104, -2.1341]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# sports

# %%
test_input = "A new technology uses artificial intelligence (AI) to help people sleep better. A company made a special pillow. This pillow listens to you while you sleep. If you snore, the pillow moves slowly. It helps you change your position to stop snoring. Many people say they sleep better with this pillow. It also connects to a smartphone app. The app tells you how well you slept. The creators believe AI will change how we rest."
test_input_processed = tokenizer(test_input, truncation=True, padding="max_length", return_tensors="pt").to(device)
logits = model(**test_input_processed).logits
print(logits)
predicted_labels = torch.argmax(logits, dim=1)

labeling_mapper = ["world", "sports", "business", "sci/tech"]
print(labeling_mapper[predicted_labels[0]])
# Out:
# tensor([[-2.3319, -2.6772,  0.4700,  3.5542]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# sci/tech

# %%
all_predictions: list[int] = []
all_labels: list[int] = []

with torch.no_grad():
    for batch in tqdm(test_loader, desc="Evaluating"):
        inputs = {key: batch[key].to(device) for key in batch}
        labels = inputs.pop("label")
        outputs = model(**inputs)
        logits = outputs.logits
        predicted_labels = torch.argmax(logits, dim=1)

        all_predictions.extend(predicted_labels.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
# Out:
# Evaluating: 100%|██████████| 100/100 [00:10<00:00,  9.15it/s]

# %%
conf_matrix = confusion_matrix(all_labels, all_predictions)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="g", cmap=sns.light_palette("#4285f4", as_cmap=True))
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
plt.title("Confusion Matrix Heatmap")
plt.show()

# %% [markdown]
# ## 모델 서빙
#
# <img width="480" alt="모델 서빙 다이어그램" src="data:image/png;base64,..." />

# %%
# 모델 체크포인트 저장.
model_save_path = "bert_news_classification_model.pth"
torch.save(model.state_dict(), model_save_path)

# %%
# %%writefile model_handler.py
import json

import torch
from ts.context import Context
from ts.torch_handler.base_handler import BaseHandler
from transformers import BatchEncoding, BertTokenizer, BertForSequenceClassification

class ModelHandler(BaseHandler):
    def __init__(self):
        self.initialized = False
        self.tokenizer = None
        self.model = None

    def initialize(self, context: Context):
        self.initialized = True
        self.tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
        self.model = BertForSequenceClassification.from_pretrained("bert-base-uncased", num_labels=4)
        self.model.load_state_dict(torch.load("bert_news_classification_model.pth"))
        self.model.to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
        self.model.eval()

    def preprocess(self, data: list[dict[str, bytearray]]) -> BatchEncoding:
        model_input_texts: list[str] = sum([json.loads(item.get("body").decode("utf-8"))["data"] for item in data], [])
        inputs = self.tokenizer(model_input_texts, truncation=True, padding=True, max_length=512, return_tensors="pt")
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        return inputs.to(device)

    def inference(self, input_batch: BatchEncoding) -> torch.Tensor:
        with torch.no_grad():
            outputs = self.model(**input_batch)
            return outputs.logits

    def postprocess(self, inference_output: torch.Tensor) -> list[dict[str, float]]:
        probabilities = torch.nn.functional.softmax(inference_output, dim=1)
        return [{"label": int(torch.argmax(prob)), "probability": float(prob.max())} for prob in probabilities]
# Out:
# Writing model_handler.py

# %%
# %%writefile config.properties
# inference_address=http://0.0.0.0:5000
# management_address=http://0.0.0.0:5001
# metrics_address=http://0.0.0.0:5002
# Out:
# Writing config.properties

# %%
# bert vocab 파일 (아티팩트)

# !wget https://raw.githubusercontent.com/microsoft/SDNet/master/bert_vocab_files/bert-base-uncased-vocab.txt \
    -O bert-base-uncased-vocab.txt
# Out:
# --2026-04-15 07:36:55--  https://raw.githubusercontent.com/microsoft/SDNet/master/bert_vocab_files/bert-base-uncased-vocab.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 231508 (226K) [text/plain]
# Saving to: ‘bert-base-uncased-vocab.txt’
#
# bert-base-uncased-v 100%[===================>] 226.08K  --.-KB/s    in 0.002s
#
# 2026-04-15 07:36:56 (101 MB/s) - ‘bert-base-uncased-vocab.txt’ saved [231508/231508]

# %%
# Torch serve archiver의 최종 파일 저장 위치.
# .mar 확장자 파일을 생성하여 패키징 하게 된다.

# !mkdir -p model-store

# %%
# !torch-model-archiver \
    --model-name bert_news_classification \
    --version 1.0 \
    --serialized-file bert_news_classification_model.pth \
    --handler ./model_handler.py \
    --extra-files "bert-base-uncased-vocab.txt" \
    --export-path model-store \
    -f

# %%
# %%script bash --bg
# PYTHONPATH=/usr/lib/python3.10 torchserve \
#     --start \
#     --ncs \
#     --ts-config config.properties \
#     --model-store model-store \
#     --models bert_news_classification=bert_news_classification.mar \
#     --disable-token-auth

# %%
# 아래와 같이 뜨면 정상 실행.
# {
#   "status": "Healthy"
# }

# !curl -X GET localhost:5000/ping
# Out:
# curl: (7) Failed to connect to localhost port 5000 after 0 ms: Connection refused

# %% [markdown]
# ### 서버 실행 실패 원인 확인

# %%
# %%script bash --bg
# # 1. 혹시 실행 중일지 모를 서버 정지
# torchserve --stop
# # 2. 로그 파일과 함께 서버 시작
# # > server_log.txt : 표준 출력을 파일에 저장
# # 2>&1 : 에러 메시지도 표준 출력과 같은 곳(파일)에 저장
# PYTHONPATH=/usr/lib/python3.10 torchserve \
#     --start \
#     --ncs \
#     --ts-config config.properties \
#     --model-store model-store \
#     --models bert_news_classification=bert_news_classification.mar \
#     --disable-token-auth > server_log.txt 2>&1

# %% [markdown]
# - 코랩이 이미 8000을 쓰고 있기에 중첩되지 않기 위해 config.properties를 작성. 그러나 실제 서빙에서는 해당 파일이 필요 없을 수도 있음

# %%
# 로그 파일의 마지막 50줄 출력
# !tail -n 50 logs/model_log.log
# 혹은 전체적인 서버 로그 확인
# !tail -n 50 logs/ts_log.log
# Out:
# tail: cannot open 'logs/model_log.log' for reading: No such file or directory
# tail: cannot open 'logs/ts_log.log' for reading: No such file or directory

# %%
# 현재 위치 확인
# !pwd
# Out:
# /content

# %%
# 로그 파일의 마지막 50줄 출력
# !tail -n 50 ./logs/model_log.log
# 혹은 전체적인 서버 로그 확인
# !tail -n 50 ./logs/ts_log.log
# Out:
# 2026-04-15T07:58:45,370 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  96%|█████████▌| 191/199 [00:00<00:00, 2227.68it/s, Materializing param=bert.encoder.layer.11.attention.self.value.weight]
# 2026-04-15T07:58:45,370 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  96%|█████████▌| 191/199 [00:00<00:00, 2224.41it/s, Materializing param=bert.encoder.layer.11.attention.self.value.weight]
# 2026-04-15T07:58:45,371 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  96%|█████████▋| 192/199 [00:00<00:00, 2208.95it/s, Materializing param=bert.encoder.layer.11.intermediate.dense.bias]
# 2026-04-15T07:58:45,371 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  96%|█████████▋| 192/199 [00:00<00:00, 2206.19it/s, Materializing param=bert.encoder.layer.11.intermediate.dense.bias]
# 2026-04-15T07:58:45,371 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  97%|█████████▋| 193/199 [00:00<00:00, 2211.06it/s, Materializing param=bert.encoder.layer.11.intermediate.dense.weight]
# 2026-04-15T07:58:45,372 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  97%|█████████▋| 193/199 [00:00<00:00, 2207.00it/s, Materializing param=bert.encoder.layer.11.intermediate.dense.weight]
# 2026-04-15T07:58:45,372 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  97%|█████████▋| 194/199 [00:00<00:00, 2213.89it/s, Materializing param=bert.encoder.layer.11.output.LayerNorm.bias]
# 2026-04-15T07:58:45,372 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  97%|█████████▋| 194/199 [00:00<00:00, 2211.74it/s, Materializing param=bert.encoder.layer.11.output.LayerNorm.bias]
# 2026-04-15T07:58:45,372 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  98%|█████████▊| 195/199 [00:00<00:00, 2217.21it/s, Materializing param=bert.encoder.layer.11.output.LayerNorm.weight]
# 2026-04-15T07:58:45,372 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  98%|█████████▊| 195/199 [00:00<00:00, 2215.37it/s, Materializing param=bert.encoder.layer.11.output.LayerNorm.weight]
# 2026-04-15T07:58:45,373 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  98%|█████████▊| 196/199 [00:00<00:00, 2223.79it/s, Materializing param=bert.encoder.layer.11.output.dense.bias]
# 2026-04-15T07:58:45,373 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  98%|█████████▊| 196/199 [00:00<00:00, 2222.39it/s, Materializing param=bert.encoder.layer.11.output.dense.bias]
# 2026-04-15T07:58:45,373 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  99%|█████████▉| 197/199 [00:00<00:00, 2230.13it/s, Materializing param=bert.encoder.layer.11.output.dense.weight]
# 2026-04-15T07:58:45,373 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  99%|█████████▉| 197/199 [00:00<00:00, 2228.56it/s, Materializing param=bert.encoder.layer.11.output.dense.weight]
# 2026-04-15T07:58:45,373 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  99%|█████████▉| 198/199 [00:00<00:00, 2236.88it/s, Materializing param=bert.pooler.dense.bias]
# 2026-04-15T07:58:45,373 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  99%|█████████▉| 198/199 [00:00<00:00, 2235.14it/s, Materializing param=bert.pooler.dense.bias]
# 2026-04-15T07:58:45,374 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights: 100%|██████████| 199/199 [00:00<00:00, 2242.60it/s, Materializing param=bert.pooler.dense.weight]
# 2026-04-15T07:58:45,374 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights: 100%|██████████| 199/199 [00:00<00:00, 2240.32it/s, Materializing param=bert.pooler.dense.weight]
# 2026-04-15T07:58:45,374 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights: 100%|██████████| 199/199 [00:00<00:00, 2236.12it/s, Materializing param=bert.pooler.dense.weight]
# 2026-04-15T07:58:45,379 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# 2026-04-15T07:58:45,379 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Key                                        | Status     |
# 2026-04-15T07:58:45,379 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - -------------------------------------------+------------+-
# 2026-04-15T07:58:45,379 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# 2026-04-15T07:58:45,379 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - cls.predictions.transform.dense.weight     | UNEXPECTED |
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - cls.seq_relationship.bias                  | UNEXPECTED |
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - cls.predictions.transform.dense.bias       | UNEXPECTED |
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - cls.seq_relationship.weight                | UNEXPECTED |
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - cls.predictions.bias                       | UNEXPECTED |
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - classifier.bias                            | MISSING    |
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - classifier.weight                          | MISSING    |
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Notes:
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# 2026-04-15T08:04:12,574 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Traceback (most recent call last):
# 2026-04-15T08:04:12,574 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -   File "/usr/local/lib/python3.12/dist-packages/ts/model_service_worker.py", line 301, in <module>
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -     worker.run_server()
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -   File "/usr/local/lib/python3.12/dist-packages/ts/model_service_worker.py", line 268, in run_server
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -     self.handle_connection(cl_socket)
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -   File "/usr/local/lib/python3.12/dist-packages/ts/model_service_worker.py", line 179, in handle_connection
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -     cmd, msg = retrieve_msg(cl_socket)
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -                ^^^^^^^^^^^^^^^^^^^^^^^
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -   File "/usr/local/lib/python3.12/dist-packages/ts/protocol/otf_message_handler.py", line 33, in retrieve_msg
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -     cmd = _retrieve_buffer(conn, 1)
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -           ^^^^^^^^^^^^^^^^^^^^^^^^^
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -   File "/usr/local/lib/python3.12/dist-packages/ts/protocol/otf_message_handler.py", line 181, in _retrieve_buffer
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -     pkt = conn.recv(length)
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -           ^^^^^^^^^^^^^^^^^
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - KeyboardInterrupt
# 2026-04-15T08:02:36,357 [WARN ] pool-3-thread-1 org.pytorch.serve.metrics.MetricCollector - Parse metrics failed: NumExpr defaulting to 12 threads.
# 2026-04-15T08:02:36,742 [INFO ] pool-3-thread-1 TS_METRICS - CPUUtilization.Percent:0.0|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,743 [INFO ] pool-3-thread-1 TS_METRICS - DiskAvailable.Gigabytes:190.79040908813477|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,743 [INFO ] pool-3-thread-1 TS_METRICS - DiskUsage.Gigabytes:44.869808197021484|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,743 [INFO ] pool-3-thread-1 TS_METRICS - DiskUtilization.Percent:19.0|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,743 [INFO ] pool-3-thread-1 TS_METRICS - GPUMemoryUtilization.Percent:23.243900321264217|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,743 [INFO ] pool-3-thread-1 TS_METRICS - GPUMemoryUsed.Megabytes:5354.0|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,743 [INFO ] pool-3-thread-1 TS_METRICS - GPUUtilization.Percent:0.0|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,743 [INFO ] pool-3-thread-1 TS_METRICS - MemoryAvailable.Megabytes:47452.8828125|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,743 [INFO ] pool-3-thread-1 TS_METRICS - MemoryUsed.Megabytes:6116.22265625|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,743 [INFO ] pool-3-thread-1 TS_METRICS - MemoryUtilization.Percent:12.5|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,834 [ERROR] Thread-5 org.pytorch.serve.metrics.MetricCollector - /usr/local/lib/python3.12/dist-packages/ts/metrics/system_metrics.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml
#
# 2026-04-15T08:02:36,834 [ERROR] Thread-5 org.pytorch.serve.metrics.MetricCollector - /usr/local/lib/python3.12/dist-packages/ts/metrics/system_metrics.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml
#
# 2026-04-15T08:03:36,359 [WARN ] pool-3-thread-1 org.pytorch.serve.metrics.MetricCollector - Parse metrics failed: NumExpr defaulting to 12 threads.
# 2026-04-15T08:03:36,359 [WARN ] pool-3-thread-1 org.pytorch.serve.metrics.MetricCollector - Parse metrics failed: NumExpr defaulting to 12 threads.
# 2026-04-15T08:03:36,748 [INFO ] pool-3-thread-1 TS_METRICS - CPUUtilization.Percent:0.0|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,748 [INFO ] pool-3-thread-1 TS_METRICS - DiskAvailable.Gigabytes:190.7904052734375|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,748 [INFO ] pool-3-thread-1 TS_METRICS - DiskUsage.Gigabytes:44.86981201171875|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,748 [INFO ] pool-3-thread-1 TS_METRICS - DiskUtilization.Percent:19.0|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,748 [INFO ] pool-3-thread-1 TS_METRICS - GPUMemoryUtilization.Percent:23.243900321264217|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,748 [INFO ] pool-3-thread-1 TS_METRICS - GPUMemoryUsed.Megabytes:5354.0|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,748 [INFO ] pool-3-thread-1 TS_METRICS - GPUUtilization.Percent:0.0|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,749 [INFO ] pool-3-thread-1 TS_METRICS - MemoryAvailable.Megabytes:47459.33984375|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,749 [INFO ] pool-3-thread-1 TS_METRICS - MemoryUsed.Megabytes:6109.765625|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,749 [INFO ] pool-3-thread-1 TS_METRICS - MemoryUtilization.Percent:12.5|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,838 [ERROR] Thread-6 org.pytorch.serve.metrics.MetricCollector - /usr/local/lib/python3.12/dist-packages/ts/metrics/system_metrics.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml
#
# 2026-04-15T08:03:36,838 [ERROR] Thread-6 org.pytorch.serve.metrics.MetricCollector - /usr/local/lib/python3.12/dist-packages/ts/metrics/system_metrics.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml
#
# 2026-04-15T08:04:12,574 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Traceback (most recent call last):
# 2026-04-15T08:04:12,574 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -   File "/usr/local/lib/python3.12/dist-packages/ts/model_service_worker.py", line 301, in <module>
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -     worker.run_server()
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -   File "/usr/local/lib/python3.12/dist-packages/ts/model_service_worker.py", line 268, in run_server
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -     self.handle_connection(cl_socket)
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -   File "/usr/local/lib/python3.12/dist-packages/ts/model_service_worker.py", line 179, in handle_connection
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -     cmd, msg = retrieve_msg(cl_socket)
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -                ^^^^^^^^^^^^^^^^^^^^^^^
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -   File "/usr/local/lib/python3.12/dist-packages/ts/protocol/otf_message_handler.py", line 33, in retrieve_msg
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -     cmd = _retrieve_buffer(conn, 1)
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -           ^^^^^^^^^^^^^^^^^^^^^^^^^
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -   File "/usr/local/lib/python3.12/dist-packages/ts/protocol/otf_message_handler.py", line 181, in _retrieve_buffer
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -     pkt = conn.recv(length)
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -           ^^^^^^^^^^^^^^^^^
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - KeyboardInterrupt

# %%
# torchserve가 설치된 경로와 버전 확인
# !which torchserve
# !torchserve --version
# Out:
# /usr/local/bin/torchserve
# TorchServe Version is 0.12.0

# %%
# 이 셀을 실행하면 로그가 화면에 바로 나옵니다. 에러가 보이면 멈춰주세요.
# !torchserve \
    --start \
    --ncs \
    --ts-config config.properties \
    --model-store model-store \
    --models bert_news_classification=bert_news_classification.mar \
    --disable-token-auth
# Out:
# WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
# 2026-04-15T07:58:29,800 [DEBUG] main org.pytorch.serve.util.ConfigManager - xpu-smi not available or failed: Cannot run program "xpu-smi": error=2, No such file or directory
# 2026-04-15T07:58:29,805 [WARN ] main org.pytorch.serve.util.ConfigManager - Your torchserve instance can access any URL to load models. When deploying to production, make sure to limit the set of allowed_urls in config.properties
# 2026-04-15T07:58:29,828 [INFO ] main org.pytorch.serve.servingsdk.impl.PluginsManager - Initializing plugins manager...
# 2026-04-15T07:58:29,912 [INFO ] main org.pytorch.serve.metrics.configuration.MetricConfiguration - Successfully loaded metrics configuration from /usr/local/lib/python3.12/dist-packages/ts/configs/metrics.yaml
# 2026-04-15T07:58:30,024 [INFO ] main org.pytorch.serve.ModelServer -
# Torchserve version: 0.12.0
# TS Home: /usr/local/lib/python3.12/dist-packages
# Current directory: /content
# Temp directory: /tmp
# Metrics config path: /usr/local/lib/python3.12/dist-packages/ts/configs/metrics.yaml
# Number of GPUs: 1
# Number of CPUs: 12
# Max heap size: 13560 M
# Python executable: /usr/bin/python3
# Config file: config.properties
# Inference address: http://0.0.0.0:5000
# Management address: http://0.0.0.0:5001
# Metrics address: http://0.0.0.0:5002
# Model Store: /content/model-store
# Initial Models: bert_news_classification=bert_news_classification.mar
# Log dir: /content/logs
# Metrics dir: /content/logs
# Netty threads: 0
# Netty client threads: 0
# Default workers per model: 1
# Blacklist Regex: N/A
# Maximum Response Size: 6553500
# Maximum Request Size: 6553500
# Limit Maximum Image Pixels: true
# Prefer direct buffer: false
# Allowed Urls: [file://.*|http(s)?://.*]
# Custom python dependency for model allowed: false
# Enable metrics API: true
# Metrics mode: LOG
# Disable system metrics: false
# Workflow Store: /content/model-store
# CPP log config: N/A
# Model config: N/A
# System metrics command: default
# Model API enabled: false
# 2026-04-15T07:58:30,036 [INFO ] main org.pytorch.serve.servingsdk.impl.PluginsManager -  Loading snapshot serializer plugin...
# 2026-04-15T07:58:30,060 [INFO ] main org.pytorch.serve.ModelServer - Loading initial models: bert_news_classification.mar
# 2026-04-15T07:58:35,723 [DEBUG] main org.pytorch.serve.wlm.ModelVersionedRefs - Adding new version 1.0 for model bert_news_classification
# 2026-04-15T07:58:35,723 [DEBUG] main org.pytorch.serve.wlm.ModelVersionedRefs - Setting default version to 1.0 for model bert_news_classification
# 2026-04-15T07:58:35,723 [INFO ] main org.pytorch.serve.wlm.ModelManager - Model bert_news_classification loaded.
# 2026-04-15T07:58:35,723 [DEBUG] main org.pytorch.serve.wlm.ModelManager - updateModel: bert_news_classification, count: 1
# 2026-04-15T07:58:35,733 [INFO ] main org.pytorch.serve.ModelServer - Initialize Inference server with: EpollServerSocketChannel.
# 2026-04-15T07:58:35,732 [DEBUG] W-9000-bert_news_classification_1.0 org.pytorch.serve.wlm.WorkerLifeCycle - Worker cmdline: [/usr/bin/python3, /usr/local/lib/python3.12/dist-packages/ts/model_service_worker.py, --sock-type, unix, --sock-name, /tmp/.ts.sock.9000, --metrics-config, /usr/local/lib/python3.12/dist-packages/ts/configs/metrics.yaml]
# 2026-04-15T07:58:35,805 [INFO ] main org.pytorch.serve.ModelServer - Inference API bind to: http://0.0.0.0:5000
# 2026-04-15T07:58:35,806 [INFO ] main org.pytorch.serve.ModelServer - Initialize Management server with: EpollServerSocketChannel.
# 2026-04-15T07:58:35,807 [INFO ] main org.pytorch.serve.ModelServer - Management API bind to: http://0.0.0.0:5001
# 2026-04-15T07:58:35,807 [INFO ] main org.pytorch.serve.ModelServer - Initialize Metrics server with: EpollServerSocketChannel.
# 2026-04-15T07:58:35,808 [INFO ] main org.pytorch.serve.ModelServer - Metrics API bind to: http://0.0.0.0:5002
# Model server started.
# 2026-04-15T07:58:36,016 [WARN ] pool-3-thread-1 org.pytorch.serve.metrics.MetricCollector - worker pid is not available yet.
# 2026-04-15T07:58:36,363 [WARN ] pool-3-thread-1 org.pytorch.serve.metrics.MetricCollector - Parse metrics failed: NumExpr defaulting to 12 threads.
# 2026-04-15T07:58:36,502 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
# 2026-04-15T07:58:36,503 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -   import pynvml  # type: ignore[import]
# 2026-04-15T07:58:36,800 [INFO ] pool-3-thread-1 TS_METRICS - CPUUtilization.Percent:0.0|#Level:Host|#hostname:bd61c62829f4,timestamp:1776239916
# 2026-04-15T07:58:36,801 [INFO ] pool-3-thread-1 TS_METRICS - DiskAvailable.Gigabytes:190.79072952270508|#Level:Host|#hostname:bd61c62829f4,timestamp:1776239916
# 2026-04-15T07:58:36,802 [INFO ] pool-3-thread-1 TS_METRICS - DiskUsage.Gigabytes:44.86948776245117|#Level:Host|#hostname:bd61c62829f4,timestamp:1776239916
# 2026-04-15T07:58:36,802 [INFO ] pool-3-thread-1 TS_METRICS - DiskUtilization.Percent:19.0|#Level:Host|#hostname:bd61c62829f4,timestamp:1776239916
# 2026-04-15T07:58:36,802 [INFO ] pool-3-thread-1 TS_METRICS - GPUMemoryUtilization.Percent:20.361205174958755|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776239916
# 2026-04-15T07:58:36,802 [INFO ] pool-3-thread-1 TS_METRICS - GPUMemoryUsed.Megabytes:4690.0|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776239916
# 2026-04-15T07:58:36,803 [INFO ] pool-3-thread-1 TS_METRICS - GPUUtilization.Percent:0.0|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776239916
# 2026-04-15T07:58:36,803 [INFO ] pool-3-thread-1 TS_METRICS - MemoryAvailable.Megabytes:47812.15234375|#Level:Host|#hostname:bd61c62829f4,timestamp:1776239916
# 2026-04-15T07:58:36,803 [INFO ] pool-3-thread-1 TS_METRICS - MemoryUsed.Megabytes:5764.9921875|#Level:Host|#hostname:bd61c62829f4,timestamp:1776239916
# 2026-04-15T07:58:36,803 [INFO ] pool-3-thread-1 TS_METRICS - MemoryUtilization.Percent:11.8|#Level:Host|#hostname:bd61c62829f4,timestamp:1776239916
# 2026-04-15T07:58:36,891 [ERROR] Thread-1 org.pytorch.serve.metrics.MetricCollector - /usr/local/lib/python3.12/dist-packages/ts/metrics/system_metrics.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml
#
# 2026-04-15T07:58:37,619 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - s_name_part0=/tmp/.ts.sock, s_name_part1=9000, pid=26984
# 2026-04-15T07:58:37,620 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - Listening on port: /tmp/.ts.sock.9000
# 2026-04-15T07:58:37,626 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - Successfully loaded /usr/local/lib/python3.12/dist-packages/ts/configs/metrics.yaml.
# 2026-04-15T07:58:37,626 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - [PID]26984
# 2026-04-15T07:58:37,627 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - Torch worker started.
# 2026-04-15T07:58:37,627 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - Python runtime: 3.12.13
# 2026-04-15T07:58:37,627 [DEBUG] W-9000-bert_news_classification_1.0 org.pytorch.serve.wlm.WorkerThread - W-9000-bert_news_classification_1.0 State change null -> WORKER_STARTED
# 2026-04-15T07:58:37,632 [INFO ] W-9000-bert_news_classification_1.0 org.pytorch.serve.wlm.WorkerThread - Connecting to: /tmp/.ts.sock.9000
# 2026-04-15T07:58:37,646 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - Connection accepted: /tmp/.ts.sock.9000.
# 2026-04-15T07:58:37,650 [DEBUG] W-9000-bert_news_classification_1.0 org.pytorch.serve.wlm.WorkerThread - Flushing req.cmd LOAD repeats 1 to backend at: 1776239917650
# 2026-04-15T07:58:37,652 [INFO ] W-9000-bert_news_classification_1.0 org.pytorch.serve.wlm.WorkerThread - Looping backend response at: 1776239917652
# 2026-04-15T07:58:37,684 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - model_name: bert_news_classification, batchSize: 1
# 2026-04-15T07:58:37,721 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - Enabled tensor cores
# 2026-04-15T07:58:37,721 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - OpenVINO is not enabled
# 2026-04-15T07:58:37,721 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - proceeding without onnxruntime
# 2026-04-15T07:58:37,722 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - Torch TensorRT not enabled
# 2026-04-15T07:58:42,422 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - NumExpr defaulting to 12 threads.
# 2026-04-15T07:58:43,505 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-04-15T07:58:43,505 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-04-15T07:58:43,505 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-04-15T07:58:43,733 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - HTTP Request: GET https://huggingface.co/api/models/bert-base-uncased/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 307 Temporary Redirect"
# 2026-04-15T07:58:43,962 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - HTTP Request: GET https://huggingface.co/api/models/google-bert/bert-base-uncased/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-04-15T07:58:44,192 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - HTTP Request: GET https://huggingface.co/api/models/bert-base-uncased/tree/main?recursive=true&expand=false "HTTP/1.1 307 Temporary Redirect"
# 2026-04-15T07:58:44,422 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - HTTP Request: GET https://huggingface.co/api/models/google-bert/bert-base-uncased/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-04-15T07:58:44,735 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/config.json "HTTP/1.1 200 OK"
# 2026-04-15T07:58:44,976 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/config.json "HTTP/1.1 200 OK"
# 2026-04-15T07:58:45,217 [INFO ] W-9000-bert_news_classification_1.0-stdout MODEL_LOG - HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# 2026-04-15T07:58:45,284 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -
# 2026-04-15T07:58:45,284 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# 2026-04-15T07:58:45,285 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   1%|          | 1/199 [00:00<00:00, 13486.51it/s, Materializing param=bert.embeddings.LayerNorm.bias]
# 2026-04-15T07:58:45,285 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   1%|          | 1/199 [00:00<00:00, 6186.29it/s, Materializing param=bert.embeddings.LayerNorm.bias]
# 2026-04-15T07:58:45,285 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   1%|          | 2/199 [00:00<00:00, 5242.88it/s, Materializing param=bert.embeddings.LayerNorm.weight]
# 2026-04-15T07:58:45,286 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   1%|          | 2/199 [00:00<00:00, 4234.53it/s, Materializing param=bert.embeddings.LayerNorm.weight]
# 2026-04-15T07:58:45,287 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   2%|▏         | 3/199 [00:00<00:00, 4438.42it/s, Materializing param=bert.embeddings.position_embeddings.weight]
# 2026-04-15T07:58:45,287 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   2%|▏         | 3/199 [00:00<00:00, 4004.75it/s, Materializing param=bert.embeddings.position_embeddings.weight]
# 2026-04-15T07:58:45,287 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   2%|▏         | 4/199 [00:00<00:00, 4397.70it/s, Materializing param=bert.embeddings.token_type_embeddings.weight]
# 2026-04-15T07:58:45,288 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   2%|▏         | 4/199 [00:00<00:00, 4103.01it/s, Materializing param=bert.embeddings.token_type_embeddings.weight]
# 2026-04-15T07:58:45,288 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   3%|▎         | 5/199 [00:00<00:00, 4314.24it/s, Materializing param=bert.embeddings.word_embeddings.weight]
# 2026-04-15T07:58:45,289 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   3%|▎         | 5/199 [00:00<00:00, 4075.31it/s, Materializing param=bert.embeddings.word_embeddings.weight]
# 2026-04-15T07:58:45,289 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   3%|▎         | 6/199 [00:00<00:00, 4262.50it/s, Materializing param=bert.encoder.layer.0.attention.output.LayerNorm.bias]
# 2026-04-15T07:58:45,289 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   3%|▎         | 6/199 [00:00<00:00, 4065.56it/s, Materializing param=bert.encoder.layer.0.attention.output.LayerNorm.bias]
# 2026-04-15T07:58:45,290 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   4%|▎         | 7/199 [00:00<00:00, 2751.91it/s, Materializing param=bert.encoder.layer.0.attention.output.LayerNorm.weight]
# 2026-04-15T07:58:45,290 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   4%|▎         | 7/199 [00:00<00:00, 2650.07it/s, Materializing param=bert.encoder.layer.0.attention.output.LayerNorm.weight]
# 2026-04-15T07:58:45,290 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   4%|▍         | 8/199 [00:00<00:00, 2828.49it/s, Materializing param=bert.encoder.layer.0.attention.output.dense.bias]
# 2026-04-15T07:58:45,291 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   4%|▍         | 8/199 [00:00<00:00, 2760.09it/s, Materializing param=bert.encoder.layer.0.attention.output.dense.bias]
# 2026-04-15T07:58:45,291 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   5%|▍         | 9/199 [00:00<00:00, 2771.36it/s, Materializing param=bert.encoder.layer.0.attention.output.dense.weight]
# 2026-04-15T07:58:45,291 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   5%|▍         | 9/199 [00:00<00:00, 2715.35it/s, Materializing param=bert.encoder.layer.0.attention.output.dense.weight]
# 2026-04-15T07:58:45,292 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   5%|▌         | 10/199 [00:00<00:00, 2852.69it/s, Materializing param=bert.encoder.layer.0.attention.self.key.bias]
# 2026-04-15T07:58:45,292 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   5%|▌         | 10/199 [00:00<00:00, 2801.24it/s, Materializing param=bert.encoder.layer.0.attention.self.key.bias]
# 2026-04-15T07:58:45,293 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   6%|▌         | 11/199 [00:00<00:00, 2411.65it/s, Materializing param=bert.encoder.layer.0.attention.self.key.weight]
# 2026-04-15T07:58:45,293 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   6%|▌         | 11/199 [00:00<00:00, 2365.29it/s, Materializing param=bert.encoder.layer.0.attention.self.key.weight]
# 2026-04-15T07:58:45,293 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   6%|▌         | 12/199 [00:00<00:00, 1986.49it/s, Materializing param=bert.encoder.layer.0.attention.self.query.bias]
# 2026-04-15T07:58:45,293 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   6%|▌         | 12/199 [00:00<00:00, 1949.03it/s, Materializing param=bert.encoder.layer.0.attention.self.query.bias]
# 2026-04-15T07:58:45,294 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   7%|▋         | 13/199 [00:00<00:00, 2046.23it/s, Materializing param=bert.encoder.layer.0.attention.self.query.weight]
# 2026-04-15T07:58:45,294 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   7%|▋         | 13/199 [00:00<00:00, 2022.78it/s, Materializing param=bert.encoder.layer.0.attention.self.query.weight]
# 2026-04-15T07:58:45,295 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   7%|▋         | 14/199 [00:00<00:00, 1961.20it/s, Materializing param=bert.encoder.layer.0.attention.self.value.bias]
# 2026-04-15T07:58:45,295 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   7%|▋         | 14/199 [00:00<00:00, 1937.45it/s, Materializing param=bert.encoder.layer.0.attention.self.value.bias]
# 2026-04-15T07:58:45,295 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   8%|▊         | 15/199 [00:00<00:00, 2027.61it/s, Materializing param=bert.encoder.layer.0.attention.self.value.weight]
# 2026-04-15T07:58:45,295 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   8%|▊         | 15/199 [00:00<00:00, 2009.86it/s, Materializing param=bert.encoder.layer.0.attention.self.value.weight]
# 2026-04-15T07:58:45,296 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   8%|▊         | 16/199 [00:00<00:00, 2104.45it/s, Materializing param=bert.encoder.layer.0.intermediate.dense.bias]
# 2026-04-15T07:58:45,296 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   8%|▊         | 16/199 [00:00<00:00, 2087.89it/s, Materializing param=bert.encoder.layer.0.intermediate.dense.bias]
# 2026-04-15T07:58:45,297 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   9%|▊         | 17/199 [00:00<00:00, 2166.28it/s, Materializing param=bert.encoder.layer.0.intermediate.dense.weight]
# 2026-04-15T07:58:45,297 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   9%|▊         | 17/199 [00:00<00:00, 2148.07it/s, Materializing param=bert.encoder.layer.0.intermediate.dense.weight]
# 2026-04-15T07:58:45,298 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   9%|▉         | 18/199 [00:00<00:00, 2213.55it/s, Materializing param=bert.encoder.layer.0.output.LayerNorm.bias]
# 2026-04-15T07:58:45,298 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:   9%|▉         | 18/199 [00:00<00:00, 2196.61it/s, Materializing param=bert.encoder.layer.0.output.LayerNorm.bias]
# 2026-04-15T07:58:45,298 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  10%|▉         | 19/199 [00:00<00:00, 2273.21it/s, Materializing param=bert.encoder.layer.0.output.LayerNorm.weight]
# 2026-04-15T07:58:45,299 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  10%|▉         | 19/199 [00:00<00:00, 2256.79it/s, Materializing param=bert.encoder.layer.0.output.LayerNorm.weight]
# 2026-04-15T07:58:45,299 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  10%|█         | 20/199 [00:00<00:00, 2339.14it/s, Materializing param=bert.encoder.layer.0.output.dense.bias]
# 2026-04-15T07:58:45,299 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  10%|█         | 20/199 [00:00<00:00, 2323.33it/s, Materializing param=bert.encoder.layer.0.output.dense.bias]
# 2026-04-15T07:58:45,300 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  11%|█         | 21/199 [00:00<00:00, 2322.92it/s, Materializing param=bert.encoder.layer.0.output.dense.weight]
# 2026-04-15T07:58:45,300 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  11%|█         | 21/199 [00:00<00:00, 2305.29it/s, Materializing param=bert.encoder.layer.0.output.dense.weight]
# 2026-04-15T07:58:45,300 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  11%|█         | 22/199 [00:00<00:00, 2340.10it/s, Materializing param=bert.encoder.layer.1.attention.output.LayerNorm.bias]
# 2026-04-15T07:58:45,300 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  11%|█         | 22/199 [00:00<00:00, 2323.48it/s, Materializing param=bert.encoder.layer.1.attention.output.LayerNorm.bias]
# 2026-04-15T07:58:45,301 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  12%|█▏        | 23/199 [00:00<00:00, 2307.76it/s, Materializing param=bert.encoder.layer.1.attention.output.LayerNorm.weight]
# 2026-04-15T07:58:45,301 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  12%|█▏        | 23/199 [00:00<00:00, 2288.65it/s, Materializing param=bert.encoder.layer.1.attention.output.LayerNorm.weight]
# 2026-04-15T07:58:45,301 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  12%|█▏        | 24/199 [00:00<00:00, 2349.80it/s, Materializing param=bert.encoder.layer.1.attention.output.dense.bias]
# 2026-04-15T07:58:45,302 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  12%|█▏        | 24/199 [00:00<00:00, 2335.20it/s, Materializing param=bert.encoder.layer.1.attention.output.dense.bias]
# 2026-04-15T07:58:45,302 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  13%|█▎        | 25/199 [00:00<00:00, 2402.07it/s, Materializing param=bert.encoder.layer.1.attention.output.dense.weight]
# 2026-04-15T07:58:45,302 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  13%|█▎        | 25/199 [00:00<00:00, 2388.66it/s, Materializing param=bert.encoder.layer.1.attention.output.dense.weight]
# 2026-04-15T07:58:45,302 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  13%|█▎        | 26/199 [00:00<00:00, 2429.15it/s, Materializing param=bert.encoder.layer.1.attention.self.key.bias]
# 2026-04-15T07:58:45,303 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  13%|█▎        | 26/199 [00:00<00:00, 2414.42it/s, Materializing param=bert.encoder.layer.1.attention.self.key.bias]
# 2026-04-15T07:58:45,303 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  14%|█▎        | 27/199 [00:00<00:00, 2414.68it/s, Materializing param=bert.encoder.layer.1.attention.self.key.weight]
# 2026-04-15T07:58:45,303 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  14%|█▎        | 27/199 [00:00<00:00, 2400.20it/s, Materializing param=bert.encoder.layer.1.attention.self.key.weight]
# 2026-04-15T07:58:45,303 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  14%|█▍        | 28/199 [00:00<00:00, 2450.97it/s, Materializing param=bert.encoder.layer.1.attention.self.query.bias]
# 2026-04-15T07:58:45,304 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  14%|█▍        | 28/199 [00:00<00:00, 2437.69it/s, Materializing param=bert.encoder.layer.1.attention.self.query.bias]
# 2026-04-15T07:58:45,304 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  15%|█▍        | 29/199 [00:00<00:00, 2422.81it/s, Materializing param=bert.encoder.layer.1.attention.self.query.weight]
# 2026-04-15T07:58:45,304 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  15%|█▍        | 29/199 [00:00<00:00, 2407.66it/s, Materializing param=bert.encoder.layer.1.attention.self.query.weight]
# 2026-04-15T07:58:45,304 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  15%|█▌        | 30/199 [00:00<00:00, 2284.85it/s, Materializing param=bert.encoder.layer.1.attention.self.value.bias]
# 2026-04-15T07:58:45,305 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  15%|█▌        | 30/199 [00:00<00:00, 2271.78it/s, Materializing param=bert.encoder.layer.1.attention.self.value.bias]
# 2026-04-15T07:58:45,305 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  16%|█▌        | 31/199 [00:00<00:00, 2258.41it/s, Materializing param=bert.encoder.layer.1.attention.self.value.weight]
# 2026-04-15T07:58:45,305 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  16%|█▌        | 31/199 [00:00<00:00, 2243.68it/s, Materializing param=bert.encoder.layer.1.attention.self.value.weight]
# 2026-04-15T07:58:45,305 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  16%|█▌        | 32/199 [00:00<00:00, 2283.59it/s, Materializing param=bert.encoder.layer.1.intermediate.dense.bias]
# 2026-04-15T07:58:45,306 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  16%|█▌        | 32/199 [00:00<00:00, 2272.80it/s, Materializing param=bert.encoder.layer.1.intermediate.dense.bias]
# 2026-04-15T07:58:45,306 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  17%|█▋        | 33/199 [00:00<00:00, 2246.33it/s, Materializing param=bert.encoder.layer.1.intermediate.dense.weight]
# 2026-04-15T07:58:45,306 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  17%|█▋        | 33/199 [00:00<00:00, 2235.91it/s, Materializing param=bert.encoder.layer.1.intermediate.dense.weight]
# 2026-04-15T07:58:45,306 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  17%|█▋        | 34/199 [00:00<00:00, 2275.77it/s, Materializing param=bert.encoder.layer.1.output.LayerNorm.bias]
# 2026-04-15T07:58:45,307 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  17%|█▋        | 34/199 [00:00<00:00, 2266.07it/s, Materializing param=bert.encoder.layer.1.output.LayerNorm.bias]
# 2026-04-15T07:58:45,307 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  18%|█▊        | 35/199 [00:00<00:00, 2298.32it/s, Materializing param=bert.encoder.layer.1.output.LayerNorm.weight]
# 2026-04-15T07:58:45,307 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  18%|█▊        | 35/199 [00:00<00:00, 2288.36it/s, Materializing param=bert.encoder.layer.1.output.LayerNorm.weight]
# 2026-04-15T07:58:45,307 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  18%|█▊        | 36/199 [00:00<00:00, 2324.72it/s, Materializing param=bert.encoder.layer.1.output.dense.bias]
# 2026-04-15T07:58:45,308 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  18%|█▊        | 36/199 [00:00<00:00, 2315.55it/s, Materializing param=bert.encoder.layer.1.output.dense.bias]
# 2026-04-15T07:58:45,308 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  19%|█▊        | 37/199 [00:00<00:00, 2355.85it/s, Materializing param=bert.encoder.layer.1.output.dense.weight]
# 2026-04-15T07:58:45,308 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  19%|█▊        | 37/199 [00:00<00:00, 2346.98it/s, Materializing param=bert.encoder.layer.1.output.dense.weight]
# 2026-04-15T07:58:45,308 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  19%|█▉        | 38/199 [00:00<00:00, 2361.20it/s, Materializing param=bert.encoder.layer.2.attention.output.LayerNorm.bias]
# 2026-04-15T07:58:45,309 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  19%|█▉        | 38/199 [00:00<00:00, 2351.38it/s, Materializing param=bert.encoder.layer.2.attention.output.LayerNorm.bias]
# 2026-04-15T07:58:45,309 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  20%|█▉        | 39/199 [00:00<00:00, 2363.09it/s, Materializing param=bert.encoder.layer.2.attention.output.LayerNorm.weight]
# 2026-04-15T07:58:45,309 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  20%|█▉        | 39/199 [00:00<00:00, 2353.23it/s, Materializing param=bert.encoder.layer.2.attention.output.LayerNorm.weight]
# 2026-04-15T07:58:45,309 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  20%|██        | 40/199 [00:00<00:00, 2270.44it/s, Materializing param=bert.encoder.layer.2.attention.output.dense.bias]
# 2026-04-15T07:58:45,309 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  20%|██        | 40/199 [00:00<00:00, 2258.80it/s, Materializing param=bert.encoder.layer.2.attention.output.dense.bias]
# 2026-04-15T07:58:45,310 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  21%|██        | 41/199 [00:00<00:00, 2242.53it/s, Materializing param=bert.encoder.layer.2.attention.output.dense.weight]
# 2026-04-15T07:58:45,310 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  21%|██        | 41/199 [00:00<00:00, 2230.67it/s, Materializing param=bert.encoder.layer.2.attention.output.dense.weight]
# 2026-04-15T07:58:45,310 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  21%|██        | 42/199 [00:00<00:00, 2263.96it/s, Materializing param=bert.encoder.layer.2.attention.self.key.bias]
# 2026-04-15T07:58:45,310 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  21%|██        | 42/199 [00:00<00:00, 2254.63it/s, Materializing param=bert.encoder.layer.2.attention.self.key.bias]
# 2026-04-15T07:58:45,310 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  22%|██▏       | 43/199 [00:00<00:00, 2290.43it/s, Materializing param=bert.encoder.layer.2.attention.self.key.weight]
# 2026-04-15T07:58:45,310 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  22%|██▏       | 43/199 [00:00<00:00, 2281.13it/s, Materializing param=bert.encoder.layer.2.attention.self.key.weight]
# 2026-04-15T07:58:45,311 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  22%|██▏       | 44/199 [00:00<00:00, 2314.27it/s, Materializing param=bert.encoder.layer.2.attention.self.query.bias]
# 2026-04-15T07:58:45,311 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  22%|██▏       | 44/199 [00:00<00:00, 2306.67it/s, Materializing param=bert.encoder.layer.2.attention.self.query.bias]
# 2026-04-15T07:58:45,311 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  23%|██▎       | 45/199 [00:00<00:00, 2336.23it/s, Materializing param=bert.encoder.layer.2.attention.self.query.weight]
# 2026-04-15T07:58:45,311 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  23%|██▎       | 45/199 [00:00<00:00, 2328.85it/s, Materializing param=bert.encoder.layer.2.attention.self.query.weight]
# 2026-04-15T07:58:45,311 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  23%|██▎       | 46/199 [00:00<00:00, 2283.61it/s, Materializing param=bert.encoder.layer.2.attention.self.value.bias]
# 2026-04-15T07:58:45,312 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  23%|██▎       | 46/199 [00:00<00:00, 2274.38it/s, Materializing param=bert.encoder.layer.2.attention.self.value.bias]
# 2026-04-15T07:58:45,312 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  24%|██▎       | 47/199 [00:00<00:00, 2304.43it/s, Materializing param=bert.encoder.layer.2.attention.self.value.weight]
# 2026-04-15T07:58:45,312 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  24%|██▎       | 47/199 [00:00<00:00, 2295.52it/s, Materializing param=bert.encoder.layer.2.attention.self.value.weight]
# 2026-04-15T07:58:45,312 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  24%|██▍       | 48/199 [00:00<00:00, 2303.24it/s, Materializing param=bert.encoder.layer.2.intermediate.dense.bias]
# 2026-04-15T07:58:45,312 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  24%|██▍       | 48/199 [00:00<00:00, 2294.42it/s, Materializing param=bert.encoder.layer.2.intermediate.dense.bias]
# 2026-04-15T07:58:45,313 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  25%|██▍       | 49/199 [00:00<00:00, 2323.56it/s, Materializing param=bert.encoder.layer.2.intermediate.dense.weight]
# 2026-04-15T07:58:45,313 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  25%|██▍       | 49/199 [00:00<00:00, 2316.56it/s, Materializing param=bert.encoder.layer.2.intermediate.dense.weight]
# 2026-04-15T07:58:45,313 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  25%|██▌       | 50/199 [00:00<00:00, 2328.07it/s, Materializing param=bert.encoder.layer.2.output.LayerNorm.bias]
# 2026-04-15T07:58:45,313 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  25%|██▌       | 50/199 [00:00<00:00, 2320.99it/s, Materializing param=bert.encoder.layer.2.output.LayerNorm.bias]
# 2026-04-15T07:58:45,313 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  26%|██▌       | 51/199 [00:00<00:00, 2347.94it/s, Materializing param=bert.encoder.layer.2.output.LayerNorm.weight]
# 2026-04-15T07:58:45,314 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  26%|██▌       | 51/199 [00:00<00:00, 2339.34it/s, Materializing param=bert.encoder.layer.2.output.LayerNorm.weight]
# 2026-04-15T07:58:45,314 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  26%|██▌       | 52/199 [00:00<00:00, 2368.38it/s, Materializing param=bert.encoder.layer.2.output.dense.bias]
# 2026-04-15T07:58:45,314 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  26%|██▌       | 52/199 [00:00<00:00, 2361.89it/s, Materializing param=bert.encoder.layer.2.output.dense.bias]
# 2026-04-15T07:58:45,314 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  27%|██▋       | 53/199 [00:00<00:00, 2368.93it/s, Materializing param=bert.encoder.layer.2.output.dense.weight]
# 2026-04-15T07:58:45,314 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  27%|██▋       | 53/199 [00:00<00:00, 2362.01it/s, Materializing param=bert.encoder.layer.2.output.dense.weight]
# 2026-04-15T07:58:45,315 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  27%|██▋       | 54/199 [00:00<00:00, 2392.39it/s, Materializing param=bert.encoder.layer.3.attention.output.LayerNorm.bias]
# 2026-04-15T07:58:45,315 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  27%|██▋       | 54/199 [00:00<00:00, 2385.21it/s, Materializing param=bert.encoder.layer.3.attention.output.LayerNorm.bias]
# 2026-04-15T07:58:45,315 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  28%|██▊       | 55/199 [00:00<00:00, 2332.27it/s, Materializing param=bert.encoder.layer.3.attention.output.LayerNorm.weight]
# 2026-04-15T07:58:45,315 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  28%|██▊       | 55/199 [00:00<00:00, 2323.32it/s, Materializing param=bert.encoder.layer.3.attention.output.LayerNorm.weight]
# 2026-04-15T07:58:45,316 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  28%|██▊       | 56/199 [00:00<00:00, 2323.16it/s, Materializing param=bert.encoder.layer.3.attention.output.dense.bias]
# 2026-04-15T07:58:45,316 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  28%|██▊       | 56/199 [00:00<00:00, 2316.15it/s, Materializing param=bert.encoder.layer.3.attention.output.dense.bias]
# 2026-04-15T07:58:45,316 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  29%|██▊       | 57/199 [00:00<00:00, 2341.44it/s, Materializing param=bert.encoder.layer.3.attention.output.dense.weight]
# 2026-04-15T07:58:45,316 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  29%|██▊       | 57/199 [00:00<00:00, 2335.47it/s, Materializing param=bert.encoder.layer.3.attention.output.dense.weight]
# 2026-04-15T07:58:45,316 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  29%|██▉       | 58/199 [00:00<00:00, 2332.40it/s, Materializing param=bert.encoder.layer.3.attention.self.key.bias]
# 2026-04-15T07:58:45,317 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  29%|██▉       | 58/199 [00:00<00:00, 2325.40it/s, Materializing param=bert.encoder.layer.3.attention.self.key.bias]
# 2026-04-15T07:58:45,317 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  30%|██▉       | 59/199 [00:00<00:00, 2333.88it/s, Materializing param=bert.encoder.layer.3.attention.self.key.weight]
# 2026-04-15T07:58:45,317 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  30%|██▉       | 59/199 [00:00<00:00, 2327.85it/s, Materializing param=bert.encoder.layer.3.attention.self.key.weight]
# 2026-04-15T07:58:45,317 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  30%|███       | 60/199 [00:00<00:00, 2354.79it/s, Materializing param=bert.encoder.layer.3.attention.self.query.bias]
# 2026-04-15T07:58:45,317 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  30%|███       | 60/199 [00:00<00:00, 2349.00it/s, Materializing param=bert.encoder.layer.3.attention.self.query.bias]
# 2026-04-15T07:58:45,318 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  31%|███       | 61/199 [00:00<00:00, 2373.09it/s, Materializing param=bert.encoder.layer.3.attention.self.query.weight]
# 2026-04-15T07:58:45,318 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  31%|███       | 61/199 [00:00<00:00, 2367.27it/s, Materializing param=bert.encoder.layer.3.attention.self.query.weight]
# 2026-04-15T07:58:45,318 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  31%|███       | 62/199 [00:00<00:00, 2254.40it/s, Materializing param=bert.encoder.layer.3.attention.self.value.bias]
# 2026-04-15T07:58:45,318 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  31%|███       | 62/199 [00:00<00:00, 2247.30it/s, Materializing param=bert.encoder.layer.3.attention.self.value.bias]
# 2026-04-15T07:58:45,318 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  32%|███▏      | 63/199 [00:00<00:00, 2234.18it/s, Materializing param=bert.encoder.layer.3.attention.self.value.weight]
# 2026-04-15T07:58:45,319 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  32%|███▏      | 63/199 [00:00<00:00, 2228.66it/s, Materializing param=bert.encoder.layer.3.attention.self.value.weight]
# 2026-04-15T07:58:45,319 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  32%|███▏      | 64/199 [00:00<00:00, 2250.26it/s, Materializing param=bert.encoder.layer.3.intermediate.dense.bias]
# 2026-04-15T07:58:45,319 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  32%|███▏      | 64/199 [00:00<00:00, 2245.34it/s, Materializing param=bert.encoder.layer.3.intermediate.dense.bias]
# 2026-04-15T07:58:45,319 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  33%|███▎      | 65/199 [00:00<00:00, 2267.66it/s, Materializing param=bert.encoder.layer.3.intermediate.dense.weight]
# 2026-04-15T07:58:45,320 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  33%|███▎      | 65/199 [00:00<00:00, 2262.90it/s, Materializing param=bert.encoder.layer.3.intermediate.dense.weight]
# 2026-04-15T07:58:45,320 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  33%|███▎      | 66/199 [00:00<00:00, 2285.35it/s, Materializing param=bert.encoder.layer.3.output.LayerNorm.bias]
# 2026-04-15T07:58:45,320 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  33%|███▎      | 66/199 [00:00<00:00, 2280.06it/s, Materializing param=bert.encoder.layer.3.output.LayerNorm.bias]
# 2026-04-15T07:58:45,320 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  34%|███▎      | 67/199 [00:00<00:00, 2301.92it/s, Materializing param=bert.encoder.layer.3.output.LayerNorm.weight]
# 2026-04-15T07:58:45,320 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  34%|███▎      | 67/199 [00:00<00:00, 2297.29it/s, Materializing param=bert.encoder.layer.3.output.LayerNorm.weight]
# 2026-04-15T07:58:45,321 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  34%|███▍      | 68/199 [00:00<00:00, 2319.48it/s, Materializing param=bert.encoder.layer.3.output.dense.bias]
# 2026-04-15T07:58:45,321 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  34%|███▍      | 68/199 [00:00<00:00, 2314.96it/s, Materializing param=bert.encoder.layer.3.output.dense.bias]
# 2026-04-15T07:58:45,321 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  35%|███▍      | 69/199 [00:00<00:00, 2335.19it/s, Materializing param=bert.encoder.layer.3.output.dense.weight]
# 2026-04-15T07:58:45,321 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  35%|███▍      | 69/199 [00:00<00:00, 2330.60it/s, Materializing param=bert.encoder.layer.3.output.dense.weight]
# 2026-04-15T07:58:45,321 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  35%|███▌      | 70/199 [00:00<00:00, 2352.18it/s, Materializing param=bert.encoder.layer.4.attention.output.LayerNorm.bias]
# 2026-04-15T07:58:45,322 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  35%|███▌      | 70/199 [00:00<00:00, 2346.43it/s, Materializing param=bert.encoder.layer.4.attention.output.LayerNorm.bias]
# 2026-04-15T07:58:45,322 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  36%|███▌      | 71/199 [00:00<00:00, 2368.08it/s, Materializing param=bert.encoder.layer.4.attention.output.LayerNorm.weight]
# 2026-04-15T07:58:45,322 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  36%|███▌      | 71/199 [00:00<00:00, 2363.36it/s, Materializing param=bert.encoder.layer.4.attention.output.LayerNorm.weight]
# 2026-04-15T07:58:45,322 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  36%|███▌      | 72/199 [00:00<00:00, 2334.02it/s, Materializing param=bert.encoder.layer.4.attention.output.dense.bias]
# 2026-04-15T07:58:45,322 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  36%|███▌      | 72/199 [00:00<00:00, 2328.00it/s, Materializing param=bert.encoder.layer.4.attention.output.dense.bias]
# 2026-04-15T07:58:45,323 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  37%|███▋      | 73/199 [00:00<00:00, 2347.28it/s, Materializing param=bert.encoder.layer.4.attention.output.dense.weight]
# 2026-04-15T07:58:45,323 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  37%|███▋      | 73/199 [00:00<00:00, 2342.59it/s, Materializing param=bert.encoder.layer.4.attention.output.dense.weight]
# 2026-04-15T07:58:45,323 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  37%|███▋      | 74/199 [00:00<00:00, 2347.71it/s, Materializing param=bert.encoder.layer.4.attention.self.key.bias]
# 2026-04-15T07:58:45,323 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  37%|███▋      | 74/199 [00:00<00:00, 2342.66it/s, Materializing param=bert.encoder.layer.4.attention.self.key.bias]
# 2026-04-15T07:58:45,323 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  38%|███▊      | 75/199 [00:00<00:00, 2354.01it/s, Materializing param=bert.encoder.layer.4.attention.self.key.weight]
# 2026-04-15T07:58:45,323 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  38%|███▊      | 75/199 [00:00<00:00, 2349.14it/s, Materializing param=bert.encoder.layer.4.attention.self.key.weight]
# 2026-04-15T07:58:45,324 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  38%|███▊      | 76/199 [00:00<00:00, 2368.15it/s, Materializing param=bert.encoder.layer.4.attention.self.query.bias]
# 2026-04-15T07:58:45,324 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  38%|███▊      | 76/199 [00:00<00:00, 2363.71it/s, Materializing param=bert.encoder.layer.4.attention.self.query.bias]
# 2026-04-15T07:58:45,324 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  39%|███▊      | 77/199 [00:00<00:00, 2288.56it/s, Materializing param=bert.encoder.layer.4.attention.self.query.weight]
# 2026-04-15T07:58:45,324 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  39%|███▊      | 77/199 [00:00<00:00, 2282.91it/s, Materializing param=bert.encoder.layer.4.attention.self.query.weight]
# 2026-04-15T07:58:45,325 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  39%|███▉      | 78/199 [00:00<00:00, 2299.56it/s, Materializing param=bert.encoder.layer.4.attention.self.value.bias]
# 2026-04-15T07:58:45,325 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  39%|███▉      | 78/199 [00:00<00:00, 2294.91it/s, Materializing param=bert.encoder.layer.4.attention.self.value.bias]
# 2026-04-15T07:58:45,325 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  40%|███▉      | 79/199 [00:00<00:00, 2313.59it/s, Materializing param=bert.encoder.layer.4.attention.self.value.weight]
# 2026-04-15T07:58:45,325 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  40%|███▉      | 79/199 [00:00<00:00, 2309.43it/s, Materializing param=bert.encoder.layer.4.attention.self.value.weight]
# 2026-04-15T07:58:45,326 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  40%|████      | 80/199 [00:00<00:00, 2326.19it/s, Materializing param=bert.encoder.layer.4.intermediate.dense.bias]
# 2026-04-15T07:58:45,326 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  40%|████      | 80/199 [00:00<00:00, 2322.04it/s, Materializing param=bert.encoder.layer.4.intermediate.dense.bias]
# 2026-04-15T07:58:45,326 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  41%|████      | 81/199 [00:00<00:00, 2331.56it/s, Materializing param=bert.encoder.layer.4.intermediate.dense.weight]
# 2026-04-15T07:58:45,326 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  41%|████      | 81/199 [00:00<00:00, 2325.91it/s, Materializing param=bert.encoder.layer.4.intermediate.dense.weight]
# 2026-04-15T07:58:45,326 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  41%|████      | 82/199 [00:00<00:00, 2343.62it/s, Materializing param=bert.encoder.layer.4.output.LayerNorm.bias]
# 2026-04-15T07:58:45,326 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights:  41%|████      | 82/199 [00:00<00:00, 2339.46it/s, Materializing param=bert.encoder.layer.4.output.LayerNorm.bias]
# ...
# 2026-04-15T07:58:45,374 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Loading weights: 100%|██████████| 199/199 [00:00<00:00, 2236.12it/s, Materializing param=bert.pooler.dense.weight]
# 2026-04-15T07:58:45,379 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# 2026-04-15T07:58:45,379 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Key                                        | Status     |
# 2026-04-15T07:58:45,379 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - -------------------------------------------+------------+-
# 2026-04-15T07:58:45,379 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# 2026-04-15T07:58:45,379 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - cls.predictions.transform.dense.weight     | UNEXPECTED |
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - cls.seq_relationship.bias                  | UNEXPECTED |
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - cls.predictions.transform.dense.bias       | UNEXPECTED |
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - cls.seq_relationship.weight                | UNEXPECTED |
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - cls.predictions.bias                       | UNEXPECTED |
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - classifier.bias                            | MISSING    |
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - classifier.weight                          | MISSING    |
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Notes:
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-04-15T07:58:45,380 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# 2026-04-15T07:58:46,360 [INFO ] W-9000-bert_news_classification_1.0 org.pytorch.serve.wlm.WorkerThread - Backend response time: 8707
# 2026-04-15T07:58:46,360 [DEBUG] W-9000-bert_news_classification_1.0 org.pytorch.serve.wlm.WorkerThread - W-9000-bert_news_classification_1.0 State change WORKER_STARTED -> WORKER_MODEL_LOADED
# 2026-04-15T07:58:46,360 [INFO ] W-9000-bert_news_classification_1.0 TS_METRICS - WorkerLoadTime.Milliseconds:10631.0|#WorkerName:W-9000-bert_news_classification_1.0,Level:Host|#hostname:bd61c62829f4,timestamp:1776239926
# 2026-04-15T07:58:46,361 [INFO ] W-9000-bert_news_classification_1.0 TS_METRICS - WorkerThreadTime.Milliseconds:4.0|#Level:Host|#hostname:bd61c62829f4,timestamp:1776239926
# 2026-04-15T07:59:36,355 [WARN ] pool-3-thread-1 org.pytorch.serve.metrics.MetricCollector - Parse metrics failed: NumExpr defaulting to 12 threads.
# 2026-04-15T07:59:36,737 [INFO ] pool-3-thread-1 TS_METRICS - CPUUtilization.Percent:0.0|#Level:Host|#hostname:bd61c62829f4,timestamp:1776239976
# 2026-04-15T07:59:36,738 [INFO ] pool-3-thread-1 TS_METRICS - DiskAvailable.Gigabytes:190.79042053222656|#Level:Host|#hostname:bd61c62829f4,timestamp:1776239976
# 2026-04-15T07:59:36,738 [INFO ] pool-3-thread-1 TS_METRICS - DiskUsage.Gigabytes:44.86979675292969|#Level:Host|#hostname:bd61c62829f4,timestamp:1776239976
# 2026-04-15T07:59:36,738 [INFO ] pool-3-thread-1 TS_METRICS - DiskUtilization.Percent:19.0|#Level:Host|#hostname:bd61c62829f4,timestamp:1776239976
# 2026-04-15T07:59:36,739 [INFO ] pool-3-thread-1 TS_METRICS - GPUMemoryUtilization.Percent:23.243900321264217|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776239976
# 2026-04-15T07:59:36,739 [INFO ] pool-3-thread-1 TS_METRICS - GPUMemoryUsed.Megabytes:5354.0|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776239976
# 2026-04-15T07:59:36,739 [INFO ] pool-3-thread-1 TS_METRICS - GPUUtilization.Percent:0.0|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776239976
# 2026-04-15T07:59:36,739 [INFO ] pool-3-thread-1 TS_METRICS - MemoryAvailable.Megabytes:47444.98046875|#Level:Host|#hostname:bd61c62829f4,timestamp:1776239976
# 2026-04-15T07:59:36,739 [INFO ] pool-3-thread-1 TS_METRICS - MemoryUsed.Megabytes:6124.19921875|#Level:Host|#hostname:bd61c62829f4,timestamp:1776239976
# 2026-04-15T07:59:36,739 [INFO ] pool-3-thread-1 TS_METRICS - MemoryUtilization.Percent:12.5|#Level:Host|#hostname:bd61c62829f4,timestamp:1776239976
# 2026-04-15T07:59:36,832 [ERROR] Thread-2 org.pytorch.serve.metrics.MetricCollector - /usr/local/lib/python3.12/dist-packages/ts/metrics/system_metrics.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml
#
# 2026-04-15T08:00:36,361 [WARN ] pool-3-thread-1 org.pytorch.serve.metrics.MetricCollector - Parse metrics failed: NumExpr defaulting to 12 threads.
# 2026-04-15T08:00:36,756 [INFO ] pool-3-thread-1 TS_METRICS - CPUUtilization.Percent:0.0|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240036
# 2026-04-15T08:00:36,756 [INFO ] pool-3-thread-1 TS_METRICS - DiskAvailable.Gigabytes:190.7904167175293|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240036
# 2026-04-15T08:00:36,756 [INFO ] pool-3-thread-1 TS_METRICS - DiskUsage.Gigabytes:44.86980056762695|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240036
# 2026-04-15T08:00:36,756 [INFO ] pool-3-thread-1 TS_METRICS - DiskUtilization.Percent:19.0|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240036
# 2026-04-15T08:00:36,756 [INFO ] pool-3-thread-1 TS_METRICS - GPUMemoryUtilization.Percent:23.243900321264217|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776240036
# 2026-04-15T08:00:36,757 [INFO ] pool-3-thread-1 TS_METRICS - GPUMemoryUsed.Megabytes:5354.0|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776240036
# 2026-04-15T08:00:36,757 [INFO ] pool-3-thread-1 TS_METRICS - GPUUtilization.Percent:0.0|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776240036
# 2026-04-15T08:00:36,757 [INFO ] pool-3-thread-1 TS_METRICS - MemoryAvailable.Megabytes:47587.43359375|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240036
# 2026-04-15T08:00:36,757 [INFO ] pool-3-thread-1 TS_METRICS - MemoryUsed.Megabytes:5981.7421875|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240036
# 2026-04-15T08:00:36,757 [INFO ] pool-3-thread-1 TS_METRICS - MemoryUtilization.Percent:12.2|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240036
# 2026-04-15T08:00:36,858 [ERROR] Thread-3 org.pytorch.serve.metrics.MetricCollector - /usr/local/lib/python3.12/dist-packages/ts/metrics/system_metrics.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml
#
# 2026-04-15T08:01:36,360 [WARN ] pool-3-thread-1 org.pytorch.serve.metrics.MetricCollector - Parse metrics failed: NumExpr defaulting to 12 threads.
# 2026-04-15T08:01:36,745 [INFO ] pool-3-thread-1 TS_METRICS - CPUUtilization.Percent:33.3|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240096
# 2026-04-15T08:01:36,746 [INFO ] pool-3-thread-1 TS_METRICS - DiskAvailable.Gigabytes:190.7904167175293|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240096
# 2026-04-15T08:01:36,746 [INFO ] pool-3-thread-1 TS_METRICS - DiskUsage.Gigabytes:44.86980056762695|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240096
# 2026-04-15T08:01:36,746 [INFO ] pool-3-thread-1 TS_METRICS - DiskUtilization.Percent:19.0|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240096
# 2026-04-15T08:01:36,746 [INFO ] pool-3-thread-1 TS_METRICS - GPUMemoryUtilization.Percent:23.243900321264217|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776240096
# 2026-04-15T08:01:36,747 [INFO ] pool-3-thread-1 TS_METRICS - GPUMemoryUsed.Megabytes:5354.0|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776240096
# 2026-04-15T08:01:36,747 [INFO ] pool-3-thread-1 TS_METRICS - GPUUtilization.Percent:0.0|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776240096
# 2026-04-15T08:01:36,747 [INFO ] pool-3-thread-1 TS_METRICS - MemoryAvailable.Megabytes:47455.4140625|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240096
# 2026-04-15T08:01:36,747 [INFO ] pool-3-thread-1 TS_METRICS - MemoryUsed.Megabytes:6113.6953125|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240096
# 2026-04-15T08:01:36,747 [INFO ] pool-3-thread-1 TS_METRICS - MemoryUtilization.Percent:12.5|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240096
# 2026-04-15T08:01:36,839 [ERROR] Thread-4 org.pytorch.serve.metrics.MetricCollector - /usr/local/lib/python3.12/dist-packages/ts/metrics/system_metrics.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml
#
# 2026-04-15T08:02:36,357 [WARN ] pool-3-thread-1 org.pytorch.serve.metrics.MetricCollector - Parse metrics failed: NumExpr defaulting to 12 threads.
# 2026-04-15T08:02:36,742 [INFO ] pool-3-thread-1 TS_METRICS - CPUUtilization.Percent:0.0|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,743 [INFO ] pool-3-thread-1 TS_METRICS - DiskAvailable.Gigabytes:190.79040908813477|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,743 [INFO ] pool-3-thread-1 TS_METRICS - DiskUsage.Gigabytes:44.869808197021484|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,743 [INFO ] pool-3-thread-1 TS_METRICS - DiskUtilization.Percent:19.0|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,743 [INFO ] pool-3-thread-1 TS_METRICS - GPUMemoryUtilization.Percent:23.243900321264217|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,743 [INFO ] pool-3-thread-1 TS_METRICS - GPUMemoryUsed.Megabytes:5354.0|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,743 [INFO ] pool-3-thread-1 TS_METRICS - GPUUtilization.Percent:0.0|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,743 [INFO ] pool-3-thread-1 TS_METRICS - MemoryAvailable.Megabytes:47452.8828125|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,743 [INFO ] pool-3-thread-1 TS_METRICS - MemoryUsed.Megabytes:6116.22265625|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,743 [INFO ] pool-3-thread-1 TS_METRICS - MemoryUtilization.Percent:12.5|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240156
# 2026-04-15T08:02:36,834 [ERROR] Thread-5 org.pytorch.serve.metrics.MetricCollector - /usr/local/lib/python3.12/dist-packages/ts/metrics/system_metrics.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml
#
# 2026-04-15T08:03:36,359 [WARN ] pool-3-thread-1 org.pytorch.serve.metrics.MetricCollector - Parse metrics failed: NumExpr defaulting to 12 threads.
# 2026-04-15T08:03:36,748 [INFO ] pool-3-thread-1 TS_METRICS - CPUUtilization.Percent:0.0|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,748 [INFO ] pool-3-thread-1 TS_METRICS - DiskAvailable.Gigabytes:190.7904052734375|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,748 [INFO ] pool-3-thread-1 TS_METRICS - DiskUsage.Gigabytes:44.86981201171875|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,748 [INFO ] pool-3-thread-1 TS_METRICS - DiskUtilization.Percent:19.0|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,748 [INFO ] pool-3-thread-1 TS_METRICS - GPUMemoryUtilization.Percent:23.243900321264217|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,748 [INFO ] pool-3-thread-1 TS_METRICS - GPUMemoryUsed.Megabytes:5354.0|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,748 [INFO ] pool-3-thread-1 TS_METRICS - GPUUtilization.Percent:0.0|#Level:Host,DeviceId:0|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,749 [INFO ] pool-3-thread-1 TS_METRICS - MemoryAvailable.Megabytes:47459.33984375|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,749 [INFO ] pool-3-thread-1 TS_METRICS - MemoryUsed.Megabytes:6109.765625|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,749 [INFO ] pool-3-thread-1 TS_METRICS - MemoryUtilization.Percent:12.5|#Level:Host|#hostname:bd61c62829f4,timestamp:1776240216
# 2026-04-15T08:03:36,838 [ERROR] Thread-6 org.pytorch.serve.metrics.MetricCollector - /usr/local/lib/python3.12/dist-packages/ts/metrics/system_metrics.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml
#
# 2026-04-15T08:04:12,574 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - Traceback (most recent call last):
# 2026-04-15T08:04:12,574 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -   File "/usr/local/lib/python3.12/dist-packages/ts/model_service_worker.py", line 301, in <module>
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -     worker.run_server()
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -   File "/usr/local/lib/python3.12/dist-packages/ts/model_service_worker.py", line 268, in run_server
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -     self.handle_connection(cl_socket)
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -   File "/usr/local/lib/python3.12/dist-packages/ts/model_service_worker.py", line 179, in handle_connection
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -     cmd, msg = retrieve_msg(cl_socket)
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -                ^^^^^^^^^^^^^^^^^^^^^^^
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -   File "/usr/local/lib/python3.12/dist-packages/ts/protocol/otf_message_handler.py", line 33, in retrieve_msg
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -     cmd = _retrieve_buffer(conn, 1)
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -           ^^^^^^^^^^^^^^^^^^^^^^^^^
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -   File "/usr/local/lib/python3.12/dist-packages/ts/protocol/otf_message_handler.py", line 181, in _retrieve_buffer
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -     pkt = conn.recv(length)
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG -           ^^^^^^^^^^^^^^^^^
# 2026-04-15T08:04:12,575 [WARN ] W-9000-bert_news_classification_1.0-stderr MODEL_LOG - KeyboardInterrupt

# %% [markdown]
# ## 다시 실행

# %%
# 1. 기존에 혹시 남아있을지 모를 프로세스 정리
# !fuser -k 5000/tcp 2>/dev/null

# 2. 서버 백그라운드 실행
get_ipython().system_raw(
    'torchserve --start --ncs --ts-config config.properties '
    '--model-store model-store '
    '--models bert_news_classification=bert_news_classification.mar '
    '--disable-token-auth > server_log.txt 2>&1 &'
)

import time
print("서버 재가동 중... 20초만 기다려주세요.")
time.sleep(20)
# Out:
# 서버 재가동 중... 20초만 기다려주세요.

# %%
# 아래와 같이 뜨면 정상 실행.
# {
#   "status": "Healthy"
# }

# !curl -X GET localhost:5000/ping
# Out:
# {
#   "status": "Healthy"
# }

# %%
# %%shell
#
# # 모델 실제 평가를 위해 외부 뉴스 기사 데이터 셋 파일 생성.
#
# cat > request_sports.json <<EOF
# {
#   "data": [
#     "Bleary-eyed from 16 hours on a Greyhound bus, he strolled into the stadium running on fumes. He’d barely slept in two days. The ride he was supposed to hitch from Charlotte to Indianapolis canceled at the last minute, and for a few nervy hours, Antonio Barnes started to have his doubts. The trip he’d waited 40 years for looked like it wasn’t going to happen.ADVERTISEMENTBut as he moved through the concourse at Lucas Oil Stadium an hour before the Colts faced the Raiders, it started to sink in. His pace quickened. His eyes widened. His voice picked up.“I got chills right now,” he said. “Chills.”Barnes, 57, is a lifer, a Colts fan since the Baltimore days. He wore No. 25 on his pee wee football team because that’s the number Nesby Glasgow wore on Sundays. He was a talent in his own right, too: one of his old coaches nicknamed him “Bird” because of his speed with the ball.Back then, he’d catch the city bus to Memorial Stadium, buy a bleacher ticket for $5 and watch Glasgow and Bert Jones, Curtis Dickey and Glenn Doughty. When he didn’t have any money, he’d find a hole in the fence and sneak in. After the game was over, he’d weasel his way onto the field and try to meet the players. “They were tall as trees,” he remembers.He remembers the last game he went to: Sept. 25, 1983, an overtime win over the Bears. Six months later the Colts would ditch Baltimore in the middle of the night, a sucker-punch some in the city never got over. But Barnes couldn’t quit them. When his entire family became Ravens fans, he refused. “The Colts are all I know,” he says.For years, when he couldn’t watch the games, he’d try the radio. And when that didn’t work, he’d follow the scroll at the bottom of a screen.“There were so many nights I’d just sit there in my cell, picturing what it’d be like to go to another game,” he says. “But you’re left with that thought that keeps running through your mind: I’m never getting out.”It’s hard to dream when you’re serving a life sentence for conspiracy to commit murder.It started with a handoff, a low-level dealer named Mickey Poole telling him to tuck a Ziploc full of heroin into his pocket and hide behind the Murphy towers. This was how young drug runners were groomed in Baltimore in the late 1970s. This was Barnes’ way in.ADVERTISEMENTHe was 12.Back then he idolized the Mickey Pooles of the world, the older kids who drove the shiny cars, wore the flashy jewelry, had the girls on their arms and made any working stiff punching a clock from 9 to 5 look like a fool. They owned the streets. Barnes wanted to own them, too.“In our world,” says his nephew Demon Brown, “the only successful people we saw were selling drugs and carrying guns.”So whenever Mickey would signal for a vial or two, Barnes would hurry over from his hiding spot with that Ziploc bag, out of breath because he’d been running so hard."
#   ]
# }
# EOF
#
# cat > request_business.json <<EOF
# {
#   "data": [
#     "DETROIT – America maintained its love affair with pickup trucks in 2023 — but a top-selling vehicle from Toyota Motor nearly ruined their tailgate party.Sales of the Toyota RAV4 compact crossover came within 10,000 units of Stellantis’ Ram pickup truck last year, a near-No. 3 ranking that would have marked the first time since 2014 that a non-pickup claimed one of the top three U.S. sales podium positions.The RAV4 has rapidly closed the gap: In 2020, the vehicle undersold the Ram truck by more than 133,000 units. Last year, it lagged by just 9,983. Stellantis sold 444,926 Ram pickups last year, a 5% decline from 2022.“Trucks are always at the top because they’re bought by not only individuals, but also fleet buyers and we saw heavy fleet buying last year,” said Michelle Krebs, an executive analyst at Cox Automotive. “The RAV4 shows that people want affordable, smaller SUVs, and the fact that there’s also a hybrid version of that makes it popular with people.”"
#   ]
# }
# EOF
#
# cat > request_sci_tech.json <<EOF
# {
#   "data": [
#     "OpenVoice comprises two AI models working together for text-to-speech conversion and voice tone cloning.The first model handles language style, accents, emotion, and other speech patterns. It was trained on 30,000 audio samples with varying emotions from English, Chinese, and Japanese speakers. The second “tone converter” model learned from over 300,000 samples encompassing 20,000 voices.By combining the universal speech model with a user-provided voice sample, OpenVoice can clone voices with very little data. This helps it generate cloned speech significantly faster than alternatives like Meta’s Voicebox.Californian startup OpenVoice comes from California-based startup MyShell, founded in 2023. With $5.6 million in early funding and over 400,000 users already, MyShell bills itself as a decentralised platform for creating and discovering AI apps.  In addition to pioneering instant voice cloning, MyShell offers original text-based chatbot personalities, meme generators, user-created text RPGs, and more. Some content is locked behind a subscription fee. The company also charges bot creators to promote their bots on its platform.By open-sourcing its voice cloning capabilities through HuggingFace while monetising its broader app ecosystem, MyShell stands to increase users across both while advancing an open model of AI development."
#   ]
# }
# EOF

# %%
# 스포츠 기사 평가 (레이블: 1)
# !curl -X POST \
    -H "Accept: application/json" \
    -T "request_sports.json" \
    http://localhost:5000/predictions/bert_news_classification
# Out:
# {
#   "label": 1,
#   "probability": 0.9814961552619934
# }

# %%
# 비즈니스 기사 평가 (레이블: 2)
# !curl -X POST \
    -H "Accept: application/json" \
    -T "request_business.json" \
    http://localhost:5000/predictions/bert_news_classification
# Out:
# {
#   "label": 2,
#   "probability": 0.969226598739624
# }

# %%
# 테크 기사 평가 (레이블: 3)
# !curl -X POST \
    -H "Accept: application/json" \
    -T "request_sci_tech.json" \
    http://localhost:5000/predictions/bert_news_classification
# Out:
# {
#   "label": 3,
#   "probability": 0.9788541793823242
# }

# %% [markdown]
# ## ngrok을 통한 외부 연결
#
# ngrok은 로컬에 서비스되는 데몬/서버에 외부 도메인을 연결시켜,
# 외부에서 접근하기 쉽도록 만들어주는 서비스입니다.
#
# 5000번으로 호스팅한 서빙 서버 접근을 위해 아래 코드에서는 ngrok을 연결합니다.

# %%
# !pip install pyngrok
# Out:
# Collecting pyngrok
#   Downloading pyngrok-8.0.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.3)
# Downloading pyngrok-8.0.0-py3-none-any.whl (24 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-8.0.0

# %%
from pyngrok import ngrok

ngrok.set_auth_token(" ")
inference_tunnel = ngrok.connect("5000")
inference_tunnel
# Out:
# <NgrokTunnel: "https://a0d1-34-143-185-86.ngrok-free.app" -> "http://localhost:5000">

# %%
# !curl -X POST \
    -H "Accept: application/json" \
    -T "request_sci_tech.json" \
    https://1c1d-34-29-238-199.ngrok-free.app/predictions/bert_news_classification
# Out:
# The endpoint 1c1d-34-29-238-199.ngrok-free.app is offline.
#
# ERR_NGROK_3200
